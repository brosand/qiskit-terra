# %% [markdown]
# # Calculation of control fields for QFT gate on two qubits using L-BFGS-B algorithm

# %% [markdown]
# Alexander Pitchford (agp1@aber.ac.uk)

# %%
cd /Users/benrosand/oct-qiskit-pulse
# Out:
# /Users/benrosand/oct-qiskit-pulse

# %% [markdown]
# ### Imports

# %%
# %matplotlib inline
import numpy as np
import matplotlib.pyplot as plt
import datetime

# %%
from qutip import Qobj, identity, sigmax, sigmay, sigmaz, tensor, hadamard_transform, basis
from qutip.qip.algorithms import qft
import qutip.logging_utils as logging
logger = logging.get_logger()
#Set this to None or logging.WARN for 'quiet' execution
log_level = logging.INFO
#QuTiP control modules
import qutip.control.pulseoptim as cpo
import qutip.control.pulsegen as pulsegen
from src.qutip_helper import convert_qutip_ham
from src.helper import *
from qiskit import IBMQ
from qutip.qip.device import Processor
from qiskit.pulse import Play, SamplePulse

from qiskit.providers.aer.pulse.system_models.hamiltonian_model import HamiltonianModel
from src.three_restructure import *
example_name = 'QFT'

# %% [markdown]
# ### Defining the physics

# %% [markdown]
# Note here that there are two controls acting on each qubit.

# %%
# subsystem_list=[0,1]
subsystem_list=[0]
IBMQ.load_account()

# provider = IBMQ.get_provider(hub='ibm-q', group='open', project='main')
provider = IBMQ.get_provider(hub='ibm-q-internal', group='deployed', project='default')
backend = provider.get_backend('ibmq_valencia')
# Out:
# /Users/benrosand/anaconda3/envs/qoc/lib/python3.8/site-packages/ipykernel/ipkernel.py:287: DeprecationWarning: `should_run_async` will not call `transform_cell` automatically in the future. Please pass the result to `transformed_cell` argument and any exception that happen during thetransform in `preprocessing_exc_tuple` in IPython 7.17 and above.
#   and should_run_async(code)

# %% [markdown]
# \begin{align} \mathcal{H}/\hbar = & \sum_{i=0}^{4}\left(\frac{\omega_{q,i}}{2}(\mathbb{I}-\sigma_i^{z})+\frac{\Delta_{i}}{2}(O_i^2-O_i)+\Omega_{d,i}D_i(t)\sigma_i^{X}\right) \\ & + J_{1,2}(\sigma_{1}^{+}\sigma_{2}^{-}+\sigma_{1}^{-}\sigma_{2}^{+}) + J_{3,4}(\sigma_{3}^{+}\sigma_{4}^{-}+\sigma_{3}^{-}\sigma_{4}^{+}) + J_{0,1}(\sigma_{0}^{+}\sigma_{1}^{-}+\sigma_{0}^{-}\sigma_{1}^{+}) + J_{2,3}(\sigma_{2}^{+}\sigma_{3}^{-}+\sigma_{2}^{-}\sigma_{3}^{+}) \\ & + \Omega_{d,0}(U_{0}^{(0,1)}(t))\sigma_{0}^{X} + \Omega_{d,1}(U_{1}^{(1,0)}(t)+U_{2}^{(1,2)}(t))\sigma_{1}^{X} \\ & + \Omega_{d,2}(U_{3}^{(2,1)}(t)+U_{4}^{(2,3)}(t))\sigma_{2}^{X} + \Omega_{d,3}(U_{6}^{(3,4)}(t)+U_{5}^{(3,2)}(t))\sigma_{3}^{X} \\ & + \Omega_{d,4}(U_{7}^{(4,3)}(t))\sigma_{4}^{X} \\ \end{align}

# %%
H_d, H_c = get_hamiltonians(backend, subsystem_list, ['wq0'])
n_ctrls = len(H_c)
U_0 = identity(3)
U_targ = get_hadamard()
# Out:
# U0
# not using control
# D0
# NEED TO FINISH sigx1 or 2
# /Users/benrosand/anaconda3/envs/qoc/lib/python3.8/site-packages/ipykernel/ipkernel.py:287: DeprecationWarning: `should_run_async` will not call `transform_cell` automatically in the future. Please pass the result to `transformed_cell` argument and any exception that happen during thetransform in `preprocessing_exc_tuple` in IPython 7.17 and above.
#   and should_run_async(code)
# /Users/benrosand/working_oct/oct-qiskit-pulse/src/three_restructure.py:34: DeprecationWarning: Importing functions/classes of the qip submodule directly from the namespace qutip is deprecated. Please import them from the submodule instead, e.g.
# from qutip.qip.operations import cnot
# from qutip.qip.circuit import QubitCircuit
#
#   h = hadamard_transform(1).full()

# %%
H_c
# Out:
# /Users/benrosand/anaconda3/envs/qoc/lib/python3.8/site-packages/ipykernel/ipkernel.py:287: DeprecationWarning: `should_run_async` will not call `transform_cell` automatically in the future. Please pass the result to `transformed_cell` argument and any exception that happen during thetransform in `preprocessing_exc_tuple` in IPython 7.17 and above.
#   and should_run_async(code)
# [Quantum object: dims = [[3], [3]], shape = (3, 3), type = oper, isherm = True
#  Qobj data =
#  [[0.         0.49671597 0.        ]
#   [0.49671597 0.         0.70246246]
#   [0.         0.70246246 0.        ]],
#  Quantum object: dims = [[3], [3]], shape = (3, 3), type = oper, isherm = True
#  Qobj data =
#  [[0.+0.j         0.-0.49671597j 0.+0.j        ]
#   [0.+0.49671597j 0.+0.j         0.-0.70246246j]
#   [0.+0.j         0.+0.70246246j 0.+0.j        ]]]

# %% [markdown]
# Multiple total evolution times will be tried. Using this approach, the minimum evolution time required to achieve the target fidelity could be determined (iteratively).
#
# Note that the timeslot duration dt is fixed, and so the number of timeslots depends on the evo_time

# %%
# Duration of each timeslot
dt = backend.configuration().dt * 1e9
# dt = 0.02
n_ts_00 = []
# n_ts_0 = list(np.arange(64,160, 32))
n_ts_list = list(np.arange(160,3200,160))
# n_ts_list = n_ts_00 + n_ts_0 + n_ts_list
# n_ts_list = [160]#, 480, 560,640]
evo_times = [dt * n for n in n_ts_list]
# List of evolution times to try
# evo_times = [1, 3, 6]
n_evo_times = len(evo_times)
evo_time = evo_times[0]
n_ts = int(float(evo_time) / dt)
#Empty list that will hold the results for each evolution time
# results = list()
n_ts_list
# Out:
# /Users/benrosand/anaconda3/envs/qoc/lib/python3.8/site-packages/ipykernel/ipkernel.py:287: DeprecationWarning: `should_run_async` will not call `transform_cell` automatically in the future. Please pass the result to `transformed_cell` argument and any exception that happen during thetransform in `preprocessing_exc_tuple` in IPython 7.17 and above.
#   and should_run_async(code)
# [160,
#  320,
#  480,
#  640,
#  800,
#  960,
#  1120,
#  1280,
#  1440,
#  1600,
#  1760,
#  1920,
#  2080,
#  2240,
#  2400,
#  2560,
#  2720,
#  2880,
#  3040]

# %% [markdown]
# ### Set the conditions which will cause the pulse optimisation to terminate

# %% [markdown]
# ### Set the initial pulse type

# %% [markdown]
# Here the linear initial pulse type is used, simply because it results in smooth final pulses

# %%
# pulse type alternatives: RND|ZERO|LIN|SINE|SQUARE|SAW|TRIANGLE|
p_type = 'LIN'
# Out:
# /Users/benrosand/anaconda3/envs/qoc/lib/python3.8/site-packages/ipykernel/ipkernel.py:287: DeprecationWarning: `should_run_async` will not call `transform_cell` automatically in the future. Please pass the result to `transformed_cell` argument and any exception that happen during thetransform in `preprocessing_exc_tuple` in IPython 7.17 and above.
#   and should_run_async(code)

# %% [markdown]
# ### Give an extension for output files

# %%
#Set to None to suppress output files
# f_ext = "{}_n_ts{}_ptype{}.txt".format(example_name, n_ts, p_type)
f_ext = None
# Out:
# /Users/benrosand/anaconda3/envs/qoc/lib/python3.8/site-packages/ipykernel/ipkernel.py:287: DeprecationWarning: `should_run_async` will not call `transform_cell` automatically in the future. Please pass the result to `transformed_cell` argument and any exception that happen during thetransform in `preprocessing_exc_tuple` in IPython 7.17 and above.
#   and should_run_async(code)

# %% [markdown]
# ### Create the optimiser objects

# %% [markdown]
# Here is the main difference between this and the Hadamard example. In this case we use a different pulseoptim function that just creates the objects that can be used to set the physics and configure the optimisation algorithm. This gives greater flexibility (shown here by seting different initial pulse parameters for each control) and is also more efficient when running multiple optimisations on the same system.

# %%
# Fidelity error target
fid_err_targ = 1e-30
# Maximum iterations for the optisation algorithm
max_iter = 2000
# Maximum (elapsed) time allowed in seconds
max_wall_time = 120
# Minimum gradient (sum of gradients squared)
# as this tends to 0 -> local minima has been found
min_grad = 1e-30
# Out:
# /Users/benrosand/anaconda3/envs/qoc/lib/python3.8/site-packages/ipykernel/ipkernel.py:287: DeprecationWarning: `should_run_async` will not call `transform_cell` automatically in the future. Please pass the result to `transformed_cell` argument and any exception that happen during thetransform in `preprocessing_exc_tuple` in IPython 7.17 and above.
#   and should_run_async(code)

# %%
optim = cpo.create_pulse_optimizer(H_d, H_c, U_0, U_targ, n_ts, evo_time, 
                amp_lbound=-.7, amp_ubound=.7, 
                fid_err_targ=fid_err_targ, min_grad=min_grad, 
                max_iter=max_iter, max_wall_time=max_wall_time, 
                optim_method='fmin_l_bfgs_b',
                method_params={'max_metric_corr':20, 'accuracy_factor':1e8},
                dyn_type='UNIT', 
                fid_params={'phase_option':'PSU'},
                init_pulse_type=p_type, 
                log_level=log_level, gen_stats=True)

# **** get handles to the other objects ****
optim.test_out_files = 0
dyn = optim.dynamics
dyn.test_out_files = 0
p_gen = optim.pulse_generator

results = run_optimizer(optim, dt, n_evo_times,dyn, p_type, n_ts, len(H_c), f_ext, evo_time, evo_times, p_gen)
# Out:
# 0748 (3.16%)
# Wall time computing propagators: 0:00:09.951357 (84.79%)
# Wall time computing forward propagation: 0:00:00.059550 (0.51%)
# Wall time computing onward propagation: 0:00:00.056741 (0.48%)
# Wall time computing gradient: 0:00:00.758509 (6.46%)
#
# **** Iterations and function calls ****
# Number of iterations: 12
# Number of fidelity function calls: 20
# Number of times fidelity is computed: 20
# Number of gradient function calls: 20
# Number of times gradients are computed: 20
# Number of times timeslot evolution is recomputed: 20
#
# **** Control amplitudes ****
# Number of control amplitude updates: 19
# Mean number of updates per iteration: 1.5833333333333333
# Number of timeslot values changed: 33440
# Mean number of timeslot changes per update: 1760.0
# Number of amplitude values changed: 66880
# Mean number of amplitude changes per update: 3520.0
# ------------------------------------
# Final evolution
# Quantum object: dims = [[3], [3]], shape = (3, 3), type = oper, isherm = False
# Qobj data =
# [[ 6.39731016e-03-7.07077662e-01j  6.40254788e-03-7.07077974e-01j
#    2.12604479e-06-2.11030521e-06j]
#  [ 6.40043283e-03-7.07077993e-01j -6.40566402e-03+7.07077586e-01j
#   -6.82436581e-06-1.08576464e-06j]
#  [-3.36259031e-06+2.19942355e-06j  6.31473865e-06+8.38991237e-07j
#    9.05811038e-03-9.99958974e-01j]]
#
# ********* Summary *****************
# Final fidelity error 2.7954638603944204e-11
# Final gradient normal 2.2519155951808317e-05
# Terminated due to function converged
# Number of iterations 12
# Completed in 0:00:11.736698 HH:MM:SS.US
# ***********************************
#
# +++++++++++++++++++++++++++++++++++
# Starting pulse optimisation for T=426.66666666666663
# +++++++++++++++++++++++++++++++++++
#
# INFO:qutip.control.optimizer:Optimising pulse(s) using GRAPE with 'fmin_l_bfgs_b' method
# INFO:qutip.control.dynamics:Setting memory optimisations for level 0
# INFO:qutip.control.dynamics:Using operator data type <class 'numpy.ndarray'>
# INFO:qutip.control.dynamics:phased dynamics generator caching True
# INFO:qutip.control.dynamics:propagator gradient caching True
# INFO:qutip.control.dynamics:eigenvector adjoint caching True
# INFO:qutip.control.dynamics:use sparse eigen decomp False
#
# ------------------------------------
# ---- Control optimisation stats ----
# **** Timings (HH:MM:SS.US) ****
# Total wall time elapsed during optimisation: 0:00:09.235320
# Wall time computing Hamiltonians: 0:00:00.283152 (3.07%)
# Wall time computing propagators: 0:00:07.637592 (82.70%)
# Wall time computing forward propagation: 0:00:00.046505 (0.50%)
# Wall time computing onward propagation: 0:00:00.044838 (0.49%)
# Wall time computing gradient: 0:00:00.581482 (6.30%)
#
# **** Iterations and function calls ****
# Number of iterations: 10
# Number of fidelity function calls: 14
# Number of times fidelity is computed: 14
# Number of gradient function calls: 14
# Number of times gradients are computed: 14
# Number of times timeslot evolution is recomputed: 14
#
# **** Control amplitudes ****
# Number of control amplitude updates: 13
# Mean number of updates per iteration: 1.3
# Number of timeslot values changed: 24960
# Mean number of timeslot changes per update: 1920.0
# Number of amplitude values changed: 49920
# Mean number of amplitude changes per update: 3840.0
# ------------------------------------
# Final evolution
# Quantum object: dims = [[3], [3]], shape = (3, 3), type = oper, isherm = False
# Qobj data =
# [[-6.95615988e-01+1.26962584e-01j -6.95613661e-01+1.26966664e-01j
#   -3.28175666e-06-6.29352534e-06j]
#  [-6.95616515e-01+1.26951024e-01j  6.95617251e-01-1.26955663e-01j
#    5.32237393e-06+8.42637499e-06j]
#  [-8.17260516e-07+1.92060130e-06j  2.01500841e-06-1.18866717e-05j
#   -9.83751830e-01+1.79533664e-01j]]
#
# ********* Summary *****************
# Final fidelity error 9.627643127174679e-11
# Final gradient normal 4.906598252277609e-05
# Terminated due to function converged
# Number of iterations 10
# Completed in 0:00:09.235320 HH:MM:SS.US
# ***********************************
#
# +++++++++++++++++++++++++++++++++++
# Starting pulse optimisation for T=462.2222222222222
# +++++++++++++++++++++++++++++++++++
#
# INFO:qutip.control.optimizer:Optimising pulse(s) using GRAPE with 'fmin_l_bfgs_b' method
# INFO:qutip.control.dynamics:Setting memory optimisations for level 0
# INFO:qutip.control.dynamics:Using operator data type <class 'numpy.ndarray'>
# INFO:qutip.control.dynamics:phased dynamics generator caching True
# INFO:qutip.control.dynamics:propagator gradient caching True
# INFO:qutip.control.dynamics:eigenvector adjoint caching True
# INFO:qutip.control.dynamics:use sparse eigen decomp False
#
# ------------------------------------
# ---- Control optimisation stats ----
# **** Timings (HH:MM:SS.US) ****
# Total wall time elapsed during optimisation: 0:00:13.933918
# Wall time computing Hamiltonians: 0:00:00.442242 (3.17%)
# Wall time computing propagators: 0:00:11.819542 (84.83%)
# Wall time computing forward propagation: 0:00:00.071445 (0.51%)
# Wall time computing onward propagation: 0:00:00.068514 (0.49%)
# Wall time computing gradient: 0:00:00.900609 (6.46%)
#
# **** Iterations and function calls ****
# Number of iterations: 11
# Number of fidelity function calls: 20
# Number of times fidelity is computed: 20
# Number of gradient function calls: 20
# Number of times gradients are computed: 20
# Number of times timeslot evolution is recomputed: 20
#
# **** Control amplitudes ****
# Number of control amplitude updates: 19
# Mean number of updates per iteration: 1.7272727272727273
# Number of timeslot values changed: 39520
# Mean number of timeslot changes per update: 2080.0
# Number of amplitude values changed: 79040
# Mean number of amplitude changes per update: 4160.0
# ------------------------------------
# Final evolution
# Quantum object: dims = [[3], [3]], shape = (3, 3), type = oper, isherm = False
# Qobj data =
# [[ 4.43023147e-01-5.51113004e-01j  4.43028302e-01-5.51117838e-01j
#    9.70197947e-07+1.04730654e-06j]
#  [ 4.43029470e-01-5.51116899e-01j -4.43025857e-01+5.51110826e-01j
#   -2.40017568e-07-2.26024467e-06j]
#  [-7.26688503e-07+6.88566353e-07j  2.46804907e-06+3.33141732e-07j
#    6.26536749e-01-7.79391880e-01j]]
#
# ********* Summary *****************
# Final fidelity error 1.2806977700563493e-11
# Final gradient normal 1.71087426415802e-05
# Terminated due to function converged
# Number of iterations 11
# Completed in 0:00:13.933918 HH:MM:SS.US
# ***********************************
#
# +++++++++++++++++++++++++++++++++++
# Starting pulse optimisation for T=497.77777777777777
# +++++++++++++++++++++++++++++++++++
#
# INFO:qutip.control.optimizer:Optimising pulse(s) using GRAPE with 'fmin_l_bfgs_b' method
# INFO:qutip.control.dynamics:Setting memory optimisations for level 0
# INFO:qutip.control.dynamics:Using operator data type <class 'numpy.ndarray'>
# INFO:qutip.control.dynamics:phased dynamics generator caching True
# INFO:qutip.control.dynamics:propagator gradient caching True
# INFO:qutip.control.dynamics:eigenvector adjoint caching True
# INFO:qutip.control.dynamics:use sparse eigen decomp False
#
# ------------------------------------
# ---- Control optimisation stats ----
# **** Timings (HH:MM:SS.US) ****
# Total wall time elapsed during optimisation: 0:00:10.653719
# Wall time computing Hamiltonians: 0:00:00.325629 (3.06%)
# Wall time computing propagators: 0:00:08.864074 (83.20%)
# Wall time computing forward propagation: 0:00:00.053307 (0.50%)
# Wall time computing onward propagation: 0:00:00.051543 (0.48%)
# Wall time computing gradient: 0:00:00.680355 (6.39%)
#
# **** Iterations and function calls ****
# Number of iterations: 10
# Number of fidelity function calls: 14
# Number of times fidelity is computed: 14
# Number of gradient function calls: 14
# Number of times gradients are computed: 14
# Number of times timeslot evolution is recomputed: 14
#
# **** Control amplitudes ****
# Number of control amplitude updates: 13
# Mean number of updates per iteration: 1.3
# Number of timeslot values changed: 29120
# Mean number of timeslot changes per update: 2240.0
# Number of amplitude values changed: 58240
# Mean number of amplitude changes per update: 4480.0
# ------------------------------------
# Final evolution
# Quantum object: dims = [[3], [3]], shape = (3, 3), type = oper, isherm = False
# Qobj data =
# [[-6.24729119e-01-3.31240901e-01j -6.24720003e-01-3.31236942e-01j
#    3.84238928e-06+1.84633048e-06j]
#  [-6.24721644e-01-3.31233846e-01j  6.24730036e-01+3.31239170e-01j
#    3.02961901e-07+2.50755526e-06j]
#  [-4.19308542e-06-6.98720887e-07j -1.01733156e-06-2.33396040e-06j
#   -8.83497585e-01-4.68435713e-01j]]
#
# ********* Summary *****************
# Final fidelity error 2.966638046331127e-11
# Final gradient normal 2.4975500131815066e-05
# Terminated due to function converged
# Number of iterations 10
# Completed in 0:00:10.653719 HH:MM:SS.US
# ***********************************
#
# +++++++++++++++++++++++++++++++++++
# Starting pulse optimisation for T=533.3333333333333
# +++++++++++++++++++++++++++++++++++
#
# INFO:qutip.control.optimizer:Optimising pulse(s) using GRAPE with 'fmin_l_bfgs_b' method
# INFO:qutip.control.dynamics:Setting memory optimisations for level 0
# INFO:qutip.control.dynamics:Using operator data type <class 'numpy.ndarray'>
# INFO:qutip.control.dynamics:phased dynamics generator caching True
# INFO:qutip.control.dynamics:propagator gradient caching True
# INFO:qutip.control.dynamics:eigenvector adjoint caching True
# INFO:qutip.control.dynamics:use sparse eigen decomp False
#
# ------------------------------------
# ---- Control optimisation stats ----
# **** Timings (HH:MM:SS.US) ****
# Total wall time elapsed during optimisation: 0:00:13.156811
# Wall time computing Hamiltonians: 0:00:00.401053 (3.05%)
# Wall time computing propagators: 0:00:11.015487 (83.72%)
# Wall time computing forward propagation: 0:00:00.066926 (0.51%)
# Wall time computing onward propagation: 0:00:00.064972 (0.49%)
# Wall time computing gradient: 0:00:00.840629 (6.39%)
#
# **** Iterations and function calls ****
# Number of iterations: 10
# Number of fidelity function calls: 16
# Number of times fidelity is computed: 16
# Number of gradient function calls: 16
# Number of times gradients are computed: 16
# Number of times timeslot evolution is recomputed: 16
#
# **** Control amplitudes ****
# Number of control amplitude updates: 15
# Mean number of updates per iteration: 1.5
# Number of timeslot values changed: 36000
# Mean number of timeslot changes per update: 2400.0
# Number of amplitude values changed: 72000
# Mean number of amplitude changes per update: 4800.0
# ------------------------------------
# Final evolution
# Quantum object: dims = [[3], [3]], shape = (3, 3), type = oper, isherm = False
# Qobj data =
# [[-4.81615346e-01-5.17732979e-01j -4.81615526e-01-5.17731307e-01j
#   -4.95123285e-07-2.60354717e-06j]
#  [-4.81614710e-01-5.17732066e-01j  4.81616390e-01+5.17732008e-01j
#    2.34293988e-07-1.24625246e-06j]
#  [ 2.70180491e-06+3.80458584e-07j  9.20015831e-07+5.83708982e-07j
#   -6.81108173e-01-7.32182803e-01j]]
#
# ********* Summary *****************
# Final fidelity error 3.5477176751896877e-12
# Final gradient normal 1.0878039995553383e-05
# Terminated due to function converged
# Number of iterations 10
# Completed in 0:00:13.156811 HH:MM:SS.US
# ***********************************
#
# +++++++++++++++++++++++++++++++++++
# Starting pulse optimisation for T=568.8888888888889
# +++++++++++++++++++++++++++++++++++
#
# INFO:qutip.control.optimizer:Optimising pulse(s) using GRAPE with 'fmin_l_bfgs_b' method
# INFO:qutip.control.dynamics:Setting memory optimisations for level 0
# INFO:qutip.control.dynamics:Using operator data type <class 'numpy.ndarray'>
# INFO:qutip.control.dynamics:phased dynamics generator caching True
# INFO:qutip.control.dynamics:propagator gradient caching True
# INFO:qutip.control.dynamics:eigenvector adjoint caching True
# INFO:qutip.control.dynamics:use sparse eigen decomp False
#
# ------------------------------------
# ---- Control optimisation stats ----
# **** Timings (HH:MM:SS.US) ****
# Total wall time elapsed during optimisation: 0:00:10.503484
# Wall time computing Hamiltonians: 0:00:00.321676 (3.06%)
# Wall time computing propagators: 0:00:08.669443 (82.54%)
# Wall time computing forward propagation: 0:00:00.052305 (0.50%)
# Wall time computing onward propagation: 0:00:00.052492 (0.50%)
# Wall time computing gradient: 0:00:00.658744 (6.27%)
#
# **** Iterations and function calls ****
# Number of iterations: 8
# Number of fidelity function calls: 12
# Number of times fidelity is computed: 12
# Number of gradient function calls: 12
# Number of times gradients are computed: 12
# Number of times timeslot evolution is recomputed: 12
#
# **** Control amplitudes ****
# Number of control amplitude updates: 11
# Mean number of updates per iteration: 1.375
# Number of timeslot values changed: 28160
# Mean number of timeslot changes per update: 2560.0
# Number of amplitude values changed: 56320
# Mean number of amplitude changes per update: 5120.0
# ------------------------------------
# Final evolution
# Quantum object: dims = [[3], [3]], shape = (3, 3), type = oper, isherm = False
# Qobj data =
# [[ 7.02958086e-01+7.64973090e-02j  7.02955018e-01+7.65005555e-02j
#   -1.73339440e-06+7.66929329e-08j]
#  [ 7.02955603e-01+7.64951736e-02j -7.02957901e-01-7.64990040e-02j
#    1.32795911e-06+6.19693833e-07j]
#  [ 1.74063506e-07+5.42561319e-07j  2.19662133e-06+9.06514768e-08j
#    9.94131185e-01+1.08181266e-01j]]
#
# ********* Summary *****************
# Final fidelity error 6.800227048131546e-12
# Final gradient normal 1.379772330959389e-05
# Terminated due to function converged
# Number of iterations 8
# Completed in 0:00:10.503484 HH:MM:SS.US
# ***********************************
#
# +++++++++++++++++++++++++++++++++++
# Starting pulse optimisation for T=604.4444444444445
# +++++++++++++++++++++++++++++++++++
#
# INFO:qutip.control.optimizer:Optimising pulse(s) using GRAPE with 'fmin_l_bfgs_b' method
# INFO:qutip.control.dynamics:Setting memory optimisations for level 0
# INFO:qutip.control.dynamics:Using operator data type <class 'numpy.ndarray'>
# INFO:qutip.control.dynamics:phased dynamics generator caching True
# INFO:qutip.control.dynamics:propagator gradient caching True
# INFO:qutip.control.dynamics:eigenvector adjoint caching True
# INFO:qutip.control.dynamics:use sparse eigen decomp False
#
# ------------------------------------
# ---- Control optimisation stats ----
# **** Timings (HH:MM:SS.US) ****
# Total wall time elapsed during optimisation: 0:00:11.252697
# Wall time computing Hamiltonians: 0:00:00.336053 (2.99%)
# Wall time computing propagators: 0:00:09.263756 (82.32%)
# Wall time computing forward propagation: 0:00:00.055595 (0.49%)
# Wall time computing onward propagation: 0:00:00.054178 (0.48%)
# Wall time computing gradient: 0:00:00.706187 (6.28%)
#
# **** Iterations and function calls ****
# Number of iterations: 9
# Number of fidelity function calls: 12
# Number of times fidelity is computed: 12
# Number of gradient function calls: 12
# Number of times gradients are computed: 12
# Number of times timeslot evolution is recomputed: 12
#
# **** Control amplitudes ****
# Number of control amplitude updates: 11
# Mean number of updates per iteration: 1.2222222222222223
# Number of timeslot values changed: 29920
# Mean number of timeslot changes per update: 2720.0
# Number of amplitude values changed: 59840
# Mean number of amplitude changes per update: 5440.0
# ------------------------------------
# Final evolution
# Quantum object: dims = [[3], [3]], shape = (3, 3), type = oper, isherm = False
# Qobj data =
# [[-5.73622047e-02-7.04803733e-01j -5.73709777e-02-7.04748073e-01j
#   -5.25367230e-06+1.58140979e-06j]
#  [-5.73343144e-02-7.04751056e-01j  5.73519717e-02+7.04804566e-01j
#   -1.10385523e-06+2.29945304e-06j]
#  [-4.88010587e-06-1.98110143e-06j -2.81347858e-06+9.75731703e-07j
#   -8.11259119e-02-9.96703861e-01j]]
#
# ********* Summary *****************
# Final fidelity error 6.551728048975747e-10
# Final gradient normal 0.00013666576709204096
# Terminated due to function converged
# Number of iterations 9
# Completed in 0:00:11.252697 HH:MM:SS.US
# ***********************************
#
# +++++++++++++++++++++++++++++++++++
# Starting pulse optimisation for T=640.0
# +++++++++++++++++++++++++++++++++++
#
# INFO:qutip.control.optimizer:Optimising pulse(s) using GRAPE with 'fmin_l_bfgs_b' method
# INFO:qutip.control.dynamics:Setting memory optimisations for level 0
# INFO:qutip.control.dynamics:Using operator data type <class 'numpy.ndarray'>
# INFO:qutip.control.dynamics:phased dynamics generator caching True
# INFO:qutip.control.dynamics:propagator gradient caching True
# INFO:qutip.control.dynamics:eigenvector adjoint caching True
# INFO:qutip.control.dynamics:use sparse eigen decomp False
#
# ------------------------------------
# ---- Control optimisation stats ----
# **** Timings (HH:MM:SS.US) ****
# Total wall time elapsed during optimisation: 0:00:17.909790
# Wall time computing Hamiltonians: 0:00:00.549676 (3.07%)
# Wall time computing propagators: 0:00:15.102126 (84.32%)
# Wall time computing forward propagation: 0:00:00.088171 (0.49%)
# Wall time computing onward propagation: 0:00:00.086116 (0.48%)
# Wall time computing gradient: 0:00:01.131035 (6.32%)
#
# **** Iterations and function calls ****
# Number of iterations: 10
# Number of fidelity function calls: 18
# Number of times fidelity is computed: 18
# Number of gradient function calls: 18
# Number of times gradients are computed: 18
# Number of times timeslot evolution is recomputed: 18
#
# **** Control amplitudes ****
# Number of control amplitude updates: 17
# Mean number of updates per iteration: 1.7
# Number of timeslot values changed: 48960
# Mean number of timeslot changes per update: 2880.0
# Number of amplitude values changed: 97920
# Mean number of amplitude changes per update: 5760.0
# ------------------------------------
# Final evolution
# Quantum object: dims = [[3], [3]], shape = (3, 3), type = oper, isherm = False
# Qobj data =
# [[ 1.76871307e-01-6.84628720e-01j  1.76867270e-01-6.84629846e-01j
#   -2.65366879e-06+5.73869395e-07j]
#  [ 1.76872785e-01-6.84628421e-01j -1.76868707e-01+6.84629392e-01j
#   -9.64409235e-07+7.90895427e-07j]
#  [-1.77080292e-06-2.08345608e-06j -1.11935243e-06-4.44300384e-07j
#    2.50131830e-01-9.68211789e-01j]]
#
# ********* Summary *****************
# Final fidelity error 6.287304010754724e-12
# Final gradient normal 1.4713884410159973e-05
# Terminated due to function converged
# Number of iterations 10
# Completed in 0:00:17.909790 HH:MM:SS.US
# ***********************************
#
# +++++++++++++++++++++++++++++++++++
# Starting pulse optimisation for T=675.5555555555555
# +++++++++++++++++++++++++++++++++++
#
# INFO:qutip.control.optimizer:Optimising pulse(s) using GRAPE with 'fmin_l_bfgs_b' method
#
# ------------------------------------
# ---- Control optimisation stats ----
# **** Timings (HH:MM:SS.US) ****
# Total wall time elapsed during optimisation: 0:00:16.975889
# Wall time computing Hamiltonians: 0:00:00.521948 (3.07%)
# Wall time computing propagators: 0:00:14.314132 (84.32%)
# Wall time computing forward propagation: 0:00:00.083188 (0.49%)
# Wall time computing onward propagation: 0:00:00.083355 (0.49%)
# Wall time computing gradient: 0:00:01.067152 (6.29%)
#
# **** Iterations and function calls ****
# Number of iterations: 10
# Number of fidelity function calls: 16
# Number of times fidelity is computed: 16
# Number of gradient function calls: 16
# Number of times gradients are computed: 16
# Number of times timeslot evolution is recomputed: 16
#
# **** Control amplitudes ****
# Number of control amplitude updates: 15
# Mean number of updates per iteration: 1.5
# Number of timeslot values changed: 45600
# Mean number of timeslot changes per update: 3040.0
# Number of amplitude values changed: 90829
# Mean number of amplitude changes per update: 6055.266666666666
# ------------------------------------
# Final evolution
# Quantum object: dims = [[3], [3]], shape = (3, 3), type = oper, isherm = False
# Qobj data =
# [[ 3.14145866e-01+6.33492161e-01j  3.14145930e-01+6.33492219e-01j
#    4.82623302e-07-3.22304378e-07j]
#  [ 3.14146239e-01+6.33492066e-01j -3.14146231e-01-6.33491980e-01j
#   -5.21704024e-07-3.22397787e-07j]
#  [ 3.46165974e-07+2.97915064e-07j  4.29775332e-07-5.65357986e-07j
#    4.44269081e-01+8.95893400e-01j]]
#
# ********* Summary *****************
# Final fidelity error 3.0031532816110484e-13
# Final gradient normal 3.4186566327693687e-06
# Terminated due to function converged
# Number of iterations 10
# Completed in 0:00:16.975889 HH:MM:SS.US

# %% [markdown]
# ### Optimise the pulse for each of the different evolution times

# %% [markdown]
# Here a loop is used to perform the optimisation for each of the evo_times given in the list above. The first optimisation is completed using the timeslot parameters passed when the optimisation objects are created. For the subsequent runs, the Dynamics object 'dyn' is used to set the timeslot parameters before the initial pulses are generated and optimisation is completed. Note that using this method, the dyn.initialize_controls method must be called with an array of the initial amplitudes before the optim.run_optimization method is called.

# %%
evo = results[0].evo_full_final
evo.tidyup(1e-3)
# len(H_c)
# Out:
# /Users/benrosand/anaconda3/envs/qoc/lib/python3.8/site-packages/ipykernel/ipkernel.py:287: DeprecationWarning: `should_run_async` will not call `transform_cell` automatically in the future. Please pass the result to `transformed_cell` argument and any exception that happen during thetransform in `preprocessing_exc_tuple` in IPython 7.17 and above.
#   and should_run_async(code)
# Quantum object: dims = [[3], [3]], shape = (3, 3), type = oper, isherm = False
# Qobj data =
# [[ 0.13324846+0.69443907j  0.13324794+0.69443805j  0.        +0.j        ]
#  [ 0.13324806+0.69443803j -0.13324795-0.69443917j  0.        +0.j        ]
#  [ 0.        +0.j          0.        +0.j          0.18844149+0.98208442j]]

# %% [markdown]
# ### Plot the initial and final amplitudes

# %%
plot_results(n_evo_times,n_ctrls,results, evo_times)
# Out:
# /Users/benrosand/anaconda3/envs/qoc/lib/python3.8/site-packages/ipykernel/ipkernel.py:287: DeprecationWarning: `should_run_async` will not call `transform_cell` automatically in the future. Please pass the result to `transformed_cell` argument and any exception that happen during thetransform in `preprocessing_exc_tuple` in IPython 7.17 and above.
#   and should_run_async(code)

# %% [markdown]
# ### Versions

# %%
pulse_seq = results[0].final_amps
# Out:
# /Users/benrosand/anaconda3/envs/qoc/lib/python3.8/site-packages/ipykernel/ipkernel.py:287: DeprecationWarning: `should_run_async` will not call `transform_cell` automatically in the future. Please pass the result to `transformed_cell` argument and any exception that happen during thetransform in `preprocessing_exc_tuple` in IPython 7.17 and above.
#   and should_run_async(code)

# %% [markdown]
# ### Run QuTip pulse simulation

# %%
init_x = backend.defaults().instruction_schedule_map.get('x',[0])
init_x
run_qutip_sim(subsystem_list, backend, pulse_seq, H_c, H_d)
def_seq = init_x.instructions[0]
def_seq=def_seq[1].pulse.get_waveform().samples
# Out:
# /Users/benrosand/anaconda3/envs/qoc/lib/python3.8/site-packages/ipykernel/ipkernel.py:287: DeprecationWarning: `should_run_async` will not call `transform_cell` automatically in the future. Please pass the result to `transformed_cell` argument and any exception that happen during thetransform in `preprocessing_exc_tuple` in IPython 7.17 and above.
#   and should_run_async(code)

# %% [markdown]
# ### Create Channels and convert qoc pulses to Qiskit pulses

# %%
# Create the base schedule

# schedule = def_cx
# schedule.draw(plot_range=[0, 1000])
qoc_programs = [generate_qiskit_program(result.final_amps, backend) for result in results]
# Out:
# /Users/benrosand/anaconda3/envs/qoc/lib/python3.8/site-packages/ipykernel/ipkernel.py:287: DeprecationWarning: `should_run_async` will not call `transform_cell` automatically in the future. Please pass the result to `transformed_cell` argument and any exception that happen during thetransform in `preprocessing_exc_tuple` in IPython 7.17 and above.
#   and should_run_async(code)

# %% [markdown]
# ### Run the assembled pulse schedule

# %%
jobs = []
for i,program in enumerate(qoc_programs):
    cur_job = backend.run(program)
    jobs.append(cur_job)
    pulse_steps = n_ts_list[i]
    cur_job.update_tags(['QOC', 'n_ts=' + str(pulse_steps)])
# job = backend.run(frequency_sweep_program)
# Out:
# /Users/benrosand/anaconda3/envs/qoc/lib/python3.8/site-packages/ipykernel/ipkernel.py:287: DeprecationWarning: `should_run_async` will not call `transform_cell` automatically in the future. Please pass the result to `transformed_cell` argument and any exception that happen during thetransform in `preprocessing_exc_tuple` in IPython 7.17 and above.
#   and should_run_async(code)

# %%
from src.helper import qubit_distribution
qubit_distribution(jobs[18].result().get_counts())
# See if 8 works
# Out:
# /Users/benrosand/anaconda3/envs/qoc/lib/python3.8/site-packages/ipykernel/ipkernel.py:287: DeprecationWarning: `should_run_async` will not call `transform_cell` automatically in the future. Please pass the result to `transformed_cell` argument and any exception that happen during thetransform in `preprocessing_exc_tuple` in IPython 7.17 and above.
#   and should_run_async(code)
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# <ipython-input-35-5ec8ca599183> in <module>
#       1 from src.helper import qubit_distribution
# ----> 2 qubit_distribution(jobs[19].result().get_counts())
#       3 # See if 8 works
#
# IndexError: list index out of range

# %%
acc ={a:0 for a in n_ts_list}
for i,job in enumerate(jobs):
    n_ts = n_ts_list[i]
    cur_acc = qubit_distribution(job.result().get_counts())[4][1]/1024
    acc[n_ts] = cur_acc
# Out:
# /Users/benrosand/anaconda3/envs/qoc/lib/python3.8/site-packages/ipykernel/ipkernel.py:287: DeprecationWarning: `should_run_async` will not call `transform_cell` automatically in the future. Please pass the result to `transformed_cell` argument and any exception that happen during thetransform in `preprocessing_exc_tuple` in IPython 7.17 and above.
#   and should_run_async(code)

# %%
acc
# Out:
# /Users/benrosand/anaconda3/envs/qoc/lib/python3.8/site-packages/ipykernel/ipkernel.py:287: DeprecationWarning: `should_run_async` will not call `transform_cell` automatically in the future. Please pass the result to `transformed_cell` argument and any exception that happen during thetransform in `preprocessing_exc_tuple` in IPython 7.17 and above.
#   and should_run_async(code)
# {160: 0.2587890625,
#  320: 0.12109375,
#  480: 0.3095703125,
#  640: 0.1953125,
#  800: 0.228515625,
#  960: 0.240234375,
#  1120: 0.146484375,
#  1280: 0.1494140625,
#  1440: 0.572265625,
#  1600: 0.1689453125,
#  1760: 0.3369140625,
#  1920: 0.40234375,
#  2080: 0.08984375,
#  2240: 0.2900390625,
#  2400: 0.3212890625,
#  2560: 0.6494140625,
#  2720: 0.228515625,
#  2880: 0.3701171875,
#  3040: 0.2294921875}

# %%
circ = QuantumCircuit(2)
circ.cnot(0,1)
# Out:
# /Users/benrosand/anaconda3/envs/qoc/lib/python3.8/site-packages/ipykernel/ipkernel.py:287: DeprecationWarning: `should_run_async` will not call `transform_cell` automatically in the future. Please pass the result to `transformed_cell` argument and any exception that happen during thetransform in `preprocessing_exc_tuple` in IPython 7.17 and above.
#   and should_run_async(code)
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-21-5715674482bf> in <module>
# ----> 1 circ = QuantumCircuit(2)
#       2 circ.cnot(0,1)
#
# NameError: name 'QuantumCircuit' is not defined

# %%
transp_circ = qiskit.transpile(circ, backend=backend)
transp_circ.data[0][0]
# Out:
# /Users/benrosand/anaconda3/envs/qoc/lib/python3.8/site-packages/ipykernel/ipkernel.py:287: DeprecationWarning: `should_run_async` will not call `transform_cell` automatically in the future. Please pass the result to `transformed_cell` argument and any exception that happen during thetransform in `preprocessing_exc_tuple` in IPython 7.17 and above.
#   and should_run_async(code)
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-22-fb23343f2345> in <module>
# ----> 1 transp_circ = qiskit.transpile(circ, backend=backend)
#       2 transp_circ.data[0][0]
#
# NameError: name 'qiskit' is not defined

# %%
processor = Processor(N=1, dims=[9])

dt = backend.configuration().dt * 1e9

# H_d = wq0 * (1 - sigmaz()) / 2
tlist = np.array([dt * i for i in range(len(def_seq[0]) + 1)])
for i,control in enumerate(H_c):
    processor.add_control(control, targets=0)
    # coef = [a[i] for a in pulse_seq]

    processor.pulses[i].coeff = def_seq[i]
    processor.pulses[i].tlist = tlist

# processor.pulses[0].coeff = seq_x
# processor.pulses[0].tlist = np.array([dt * i for i in range(len(seq_x)+1)])
# processor.add_control(H_c[0], targets=[0], label='sigmax')
# processor.add_control(H_d, targets=[0], label="drift")
processor.add_drift(H_d, targets=[0])

basis0 = basis(9, 0)
# basis0 = basis(4,0) + basis(4,2)
result = processor.run_state(init_state=basis0)

result.states[-1].tidyup(1.e-3)
# Out:
# /Users/benrosand/anaconda3/envs/qoc/lib/python3.8/site-packages/ipykernel/ipkernel.py:287: DeprecationWarning: `should_run_async` will not call `transform_cell` automatically in the future. Please pass the result to `transformed_cell` argument and any exception that happen during thetransform in `preprocessing_exc_tuple` in IPython 7.17 and above.
#   and should_run_async(code)
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-36-c061135a6d5d> in <module>
#       4
#       5 # H_d = wq0 * (1 - sigmaz()) / 2
# ----> 6 tlist = np.array([dt * i for i in range(len(def_seq[0]) + 1)])
#       7 for i,control in enumerate(H_c):
#       8     processor.add_control(control, targets=0)
#
# TypeError: object of type 'numpy.complex128' has no len()
